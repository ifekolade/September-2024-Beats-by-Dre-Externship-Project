# %% [markdown]
# <a href="https://colab.research.google.com/github/ifekolade/September-2024-Beats-by-Dre-Externship-Project/blob/main/Copy_of_Beats_by_Dre_Consumer_Insights_Capstone_Project_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Capstone Project: Consumer Insights Data Analytics Externship of Beats by Dre

# %% [markdown]
# ## 1. Title Page
# **Project Title:** Consumer Insights Data Analytics Externship of Beats by Dre
# **Student Name:** Ifeoluwapo Kolade
# **Date:** 09/08/2024

# %% [markdown]
# Student Name: Ifeoluwapo Kolade
# Date: September 8th 2024
#
# ---

# %% [markdown]
# ## 2. Table of Contents
# 1. Introduction
# 2. Data Description
# 3. Exploratory Data Analysis (EDA)
# 4. Sentiment Analysis
# 5. AI-Generated Insights
# 6. Comparative Analysis
# 7. Strategic Recommendations
# 8. Conclusion
# 9. References

# %% [markdown]
# ## 3. Introduction
#
# ### 3.1 Project Overview

# %% [markdown]
# I undertook this project to solve data challenges in the field of consumer analytics. The project involved gathering data from multiple sources and using technology to extract information. Finally, that information would be used to provide insights to Beats By Dre.
#  The key objectives of the project were to:
#  1. Perform gathering and Cleaning of Data from product reviews
#  2. Analyse the information using toold such as Artificial Intelligence
#  3. Provide insights for the company based on the previous procedures
#
#  In addition, gathering data enabled me to compare Beats By Dre to its competitors and gain an understanding of how its products measured up in key areas of performance. Throughout this project, I will showcase the steps necessary to ensure this was carried out effectively and efficiently.

# %% [markdown]
# ### 3.2 Background
#  Context about Beats by Dre and the importance of consumer sentiment analysis in the tech industry.

# %% [markdown]
# Consumer Sentiment Analysis is of utmost importance in all consumer-centered industries. Particularly, tech relies on the experience of product users to understand what changes need to be implemented in product development. It also provides companies with a strategic advantage because it helps those making the products truly understand the needs and wants of their consumers. This results in a more personalised and focused effort in innovation and more effective updates. It helps in tailoring changes spectifically to consumer tastes.

# %% [markdown]
# ## 4. Data Description
#
# ### 4.1 Data Sources

# %% [markdown]
# The primary source for my data was reviews on Amazon. I searched up multiple products and collected data from their respective reviews by different people on amazon.com.

# %% [markdown]
# ### 4.2 Data Collection

# %% [markdown]
# I found the Beats Pill on Amazon and 5 of its competitors. Using the OxyLabs Scraper, I was able to extract the reviews from the URLs of these products. I used different page numbers in order to get the maximum amount of reviews I could. Then the results were compiled in  multiple CSV files and merged into one.
#
# The biggest challenge was the learning curve of working with the Scraper tool. However, after watching the tutorial videos, I was able to use it seamlessly.

# %% [markdown]
# ### 4.3 Data Cleaning

# %% [markdown]
# NumPy was used to identify the missing values, outliers and converting categorical columns to numeric values.

# %%
import pandas as pd

df_1 = pd.read_csv('/content/reviews_3.csv')
df_2 = pd.read_csv('/content/reviews_4.csv')
df_3 = pd.read_csv('/content/reviews_5.csv')
df_4 = pd.read_csv('/content/reviews_6.csv')
df_5 = pd.read_csv('/content/reviews_8.csv')
df_6 = pd.read_csv('/content/reviews_9.csv')
df_6.head()
merged_df = pd.concat([df_1, df_2, df_3, df_4, df_5, df_6])

merged_df.to_csv('merged_data.csv', index=False)

merged_df = pd.read_csv('merged_data.csv')

# Convert the 'rating' column to numeric, forcing errors to NaN
merged_df['ratings_numeric'] = pd.to_numeric(merged_df['rating'], errors='coerce') # 'rating' is the correct column name, not 'ratings'

# Drop rows with NaN values in the 'ratings_numeric' column
df_numerical = merged_df.dropna(subset=['ratings_numeric'])

# Print the DataFrame with numerical ratings
print(df_numerical)
# Out:
#           review_id  product_id  \
# 0    R2SSSH04J4J264  B0D4SX9RC6
# 1    R39X7USU3OX34C  B0D4SX9RC6
# 2     R4BQHA0TLLJNN  B0D4SX9RC6
# 3    R3SO3HMV0YC0WB  B0D4SX9RC6
# 4    R1BHCCLK5GZ5VZ  B0D4SX9RC6
# ..              ...         ...
# 145  R34RYWWSMDSNX0  B016XTADG2
# 146  R2VDOKHE64XK6Y  B016XTADG2
# 147  R1MR5X37HINHOH  B016XTADG2
# 148  R30D64ODNZT2B5  B016XTADG2
# 149  R2ZLGMZTX5HH9S  B016XTADG2
#
#                                                  title            author  \
# 0    5.0 out of 5 stars Really nice portable speake...           Bruce C
# 1                       5.0 out of 5 stars Really good            Justin
# 2    5.0 out of 5 stars The best Speaker I have eve...              Leox
# 3                        5.0 out of 5 stars Beats pill  Bryan Pennington
# 4                        5.0 out of 5 stars Beats Pill  Gregory Stratman
# ..                                                 ...               ...
# ...

# %% [markdown]
# ## 5. Exploratory Data Analysis (EDA)
#
# ### 5.1 Data Overview

# %%
import pandas as pd

df = pd.read_csv('/content/sample_df.csv')

# %% [markdown]
# Mean of Column 1: 54.1
# Mean of Column 2: 39.0
# Mean of Column 3: 41.4
# Mean of Dataset:44.7
#
# Mode:reviews      Excellent quality and value for money.
# sentiment                                    -0.975
#
# Standard deviation of col1: 30.12732240932731
#
# Variance of col1: 907.6555555555556
#
# Variance of col2: 442.0
#
# Variance of col3: 456.9333333333333
#
# Standard deviation of col2: 21.02379604162864
#
# Variance of col1: 907.6555555555556
#
# Variance of col2: 442.0
#
# Variance of col3: 456.9333333333333
#
# Standard deviation of col3: 21.375999001995982
#
# Variance of col1: 907.6555555555556
#
# Variance of col2: 442.0
#
# Variance of col3: 456.9333333333333

# %% [markdown]
# ### 5.2 Visualizations

# %%
# Step 2
sample_df = pd.read_csv('/content/sample_df.csv')
# Histograms
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

sample_df.hist(figsize=(10, 6))
plt.tight_layout()
plt.show()

#Box plot
sample_df.boxplot(figsize=(10, 6))
plt.title("Box Plot of Sample Data")
plt.xlabel("Columns")
plt.ylabel("Values")
plt.show()

#Scatter Plots
plt.figure(figsize=(8, 6))
plt.scatter(sample_df['col1'], sample_df['col2'])
plt.title("Scatter Plot of col1 vs col2")
plt.xlabel("col1")
plt.ylabel("col2")
plt.show()

plt.figure(figsize=(8, 6))
plt.scatter(sample_df['col2'], sample_df['col3'])
plt.title("Scatter Plot of col2 vs col3")
plt.xlabel("col2")
plt.ylabel("col3")
plt.show()

plt.figure(figsize=(8, 6))
plt.scatter(sample_df['col1'], sample_df['col3'])
plt.title("Scatter Plot of col1 vs col3")
plt.xlabel("col1")
plt.ylabel("col3")
plt.show()

# %% [markdown]
# Explanation: Interpretation of Histogram, Box Plot, Scatterplot
#
#  Results: Each column has a perfect positive correlation with itself
# Column 1 and 2 have a weak negative correlation (-0.27) Column 1 and 3 have a moderate negative correlation (-0.63) Column 2 and 3 have a weak positive correlation (0.3)

# %% [markdown]
# ### 5.3 Descriptive Statistics

# %% [markdown]
# Key findings: Both Columns 2 and 3 Correlate negatively with with column 1. Additionally, column 3 had the widest range of values which could explain the correlation.

# %% [markdown]
# ## 6. Sentiment Analysis
#
# ### 6.1 Methodology

# %% [markdown]
# For the sentiment analysis, textblob was used to assign sentiment scores to each of the reviews. Additionally, it used these scores to classify the reviews into negative and positive reviews. There was also the option of neutral review.
#
# This is an example using sample reviews

# %%
# Positive, Negative and Neutral Sentiment
import pandas as pd
from textblob import TextBlob

reviews = [
    "Great product! I love it!",
    "It's okay, but not what I expected.",
    "Very disappointed with this product.",
    "Excellent quality and value for money.",
    "I would not recommend this product.",
    "It's a good product, but a bit overpriced.",
    "I'm very satisfied with this purchase.",
    "It's a great product for the price.",
    "I'm not sure if I would buy it again.",
    "I'm very happy with this product",
]

sample_df = pd.DataFrame({'reviews': reviews})

def classify_sentiment(text):
    blob = TextBlob(text)
    sentiment_polarity = blob.sentiment.polarity

    if sentiment_polarity > 0:
        return 'Positive'
    elif sentiment_polarity < 0:
        return 'Negative'
    else:
        return 'Neutral'

sample_df['sentiment'] = sample_df['reviews'].apply(classify_sentiment)

print(sample_df)
# Out:
#                                       reviews sentiment
# 0                   Great product! I love it!  Positive
# 1         It's okay, but not what I expected.  Positive
# 2        Very disappointed with this product.  Negative
# 3      Excellent quality and value for money.  Positive
# 4         I would not recommend this product.   Neutral
# 5  It's a good product, but a bit overpriced.  Positive
# 6      I'm very satisfied with this purchase.  Positive
# 7         It's a great product for the price.  Positive
# 8       I'm not sure if I would buy it again.  Negative
# 9            I'm very happy with this product  Positive

# %% [markdown]
# ### 6.2 Results

# %%
# Positive, Negative and Neutral Sentiment
import pandas as pd
from textblob import TextBlob

reviews_df = pd.read_csv('reviews_3.csv')

reviews = reviews_df['content'].tolist()

reviews = reviews_df['content'].tolist()

def classify_sentiment(text):
    blob = TextBlob(text)
    sentiment_polarity = blob.sentiment.polarity

    if sentiment_polarity > 0:
        return 'Positive'
    elif sentiment_polarity < 0:
        return 'Negative'
    else:
        return 'Neutral'

reviews_df['sentiment'] = reviews_df['content'].apply(classify_sentiment)

print(reviews_df)
# Out:
#         review_id  product_id  \
# 0  R2SSSH04J4J264  B0D4SX9RC6
# 1  R39X7USU3OX34C  B0D4SX9RC6
# 2   R4BQHA0TLLJNN  B0D4SX9RC6
# 3  R3SO3HMV0YC0WB  B0D4SX9RC6
# 4  R1BHCCLK5GZ5VZ  B0D4SX9RC6
# 5  R102ZHXOOGDR18  B0D4SX9RC6
# 6  R3EOM3PFJ90D5Y  B0D4SX9RC6
# 7  R2EVRTXO9M1YF7  B0D4SX9RC6
# 8   RTDXQGCW5S0SA  B0D4SX9RC6
# 9  R10YJBZGOB4SBS  B0D4SX9RC6
#
#                                                title            author  \
# 0  5.0 out of 5 stars Really nice portable speake...           Bruce C
# 1                     5.0 out of 5 stars Really good            Justin
# 2  5.0 out of 5 stars The best Speaker I have eve...              Leox
# 3                      5.0 out of 5 stars Beats pill  Bryan Pennington
# 4                      5.0 out of 5 stars Beats Pill  Gregory Stratman
# 5      5.0 out of 5 stars Amazing sound for the size            Maxy D
# 6  3.0 out of 5 stars Good design, but bass disto...            Daniel
# ...

# %% [markdown]
# This snippet of code shows the reviews for the product are overwhelmingly positive. Furthermore, below I have a wordcloud generated from words in the reviews.

# %%
# Import necessary libraries
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

# Load the dataframe containing the reviews
df = pd.read_csv('/content/merged_data.csv')

# %%
text = " ".join(review for review in df.content)

# %%
# Create stopword list:
stopwords = set(STOPWORDS)

# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## 7. AI-Generated Insights
#
# ### 7.1 Using Gemini AI

# %% [markdown]
# Gemini AI was used to analyze the multiple reviews and provide a general understanding of what consumer complaints were.

# %%
import pandas as pd
import google.generativeai as genai

# Load your dataset
df = pd.read_csv('/content/merged_data.csv')

# Replace 'your_api_key' with the actual API key
api_key = "AIzaSyDKYfiV6NN6OE77Qf_T8r0x1tdrjbF1WKY"

# Function to analyze reviews using Gemini AI
def analyze_reviews(reviews, api_key,prompt_message):
    genai.configure(api_key=api_key)

    model = genai.GenerativeModel(
        model_name="gemini-1.5-flash",
        generation_config={
            "temperature": 1,
            "top_p": 0.95,
            "top_k": 64,
            "max_output_tokens": 8192,
            "response_mime_type": "text/plain",
        },
    )

    chat_session = model.start_chat(history=[])

    prompt = prompt_message + "\n\n".join(reviews)
    response = chat_session.send_message(prompt)
    return response.text

    # Select a subset of reviews

reviews_column_name = 'content'
reviews = df[reviews_column_name].head(100).tolist()

# Send prompts
prompt_message = "Analyze the negative reviews and highlight possible  points of improvement in the product:"
insights = analyze_reviews(reviews, api_key, prompt_message)
print(insights)
# Out:
# Based on the reviews, here's an analysis of the negative points and suggestions for improvement for portable Bluetooth speakers in general,  and specific points relevant to the reviewed Beats Pill and Sony ULT Field 1:
#
#
# **General Issues and Improvements for Portable Bluetooth Speakers:**
#
# * **Bass Distortion at Higher Volumes:** Several reviews mention bass distortion at higher volumes across different brands (Beats, Sony).  This suggests a need for improved amplifier design and speaker component selection to handle higher power levels without compromising sound quality.  Better signal processing to manage bass frequencies at higher volumes could also help.
#
# ...

# %% [markdown]
# ### 7.2 Key Insights
# Summary of key insights generated by Gemini AI, including specific examples of prompts used and the responses received.

# %% [markdown]
# Unique Prompt 1: Analyze the negative reviews and highlight possible  points of improvement in the product.
# Insight Generated Summary: The Beats Pill 2024 faces criticism for lacking a dedicated app, having sound quality issues, and limited connectivity options, with users calling for improvements in these areas along with clearer ecosystem integration.
#
# Unique Prompt 2: Summarize the positive reviews and list 3 strengths of the beats product.
# Insight Generated Summary 2: The Beats Pill 2024 is widely praised for its exceptional sound quality, seamless Apple integration, and versatile portability, offering impressive features like long battery life and water resistance at a competitive price point.
#
# Unique Prompt 3:Examine all the reviews and summarize what beats is doing worse than the other brands.
# Insight Generated Summary:The Beats Pill 2024 lags behind competitors like JBL, Sony, and Marshall in areas such as bass quality at high volumes, lack of a control app, and limited EQ customization options.

# %% [markdown]
# ### 7.3 Interpretation

# %% [markdown]
# The interpretation of the insights can be broken down in two main categories:
#
# - The development of an app
# - Sound quality
#
# These insights help Beats by Dre Understand that their customers, although satisfied, may be looking for some new features in new iterations.

# %% [markdown]
# ## 8. Comparative Analysis
#
# ### 8.1 Competitor Overview

# %% [markdown]
# The Competitors of the beats pill are the following:
# 1. JBL Flip 6: https://www.amazon.com/JBL-Flip-Bluetooth-Waterproof-PartyBoost/dp/B09GJZKQ3K
#  2. Bose Soundlink Revolve+: https://www.amazon.com/Bose-SoundLink-Portable-Long-Lasting-Bluetooth/dp/B06XCW4VFS
#  3. Sony ULT Field 1: https://www.amazon.com/Sony-Bluetooth-Waterproof-Shockproof-Detachable/dp/B0CXL5KTBD?th=1
#  4. Marshall Emberton II Portable bluetooth speaker: https://www.amazon.com/Marshall-Emberton-Portable-Bluetooth-Speaker/dp/B09XXW54QG?th=1
#  5. Anker Soundcore Bluetooth Speaker: https://www.amazon.com/Anker-SoundCore-Playtime-Bluetooth-Portable/dp/B016XTADG2?source=ps-sl-shoppingads-lpcontext&ref_=fplfs&smid=A294P4X9EWVXLJ&th=1
#
# JBL- Customers really like the size of the speaker and its bluetooth connectivity.
#
# Bose SoundLink Revolve+ - Great Sound quality
#
# Sony ULT Field 1 - Seamless Customizeable settings, Good bluetooth connectivity and good bass.
#
# Marshall Emberton II - Great Sound quality.
#
# Anker Soundcore - Very affordable with good connectivity to user's phones.

# %% [markdown]
# ### 8.2 Comparison of Sentiments

# %%
# Positive, Negative and Neutral Sentiment
import pandas as pd
from textblob import TextBlob

reviews_df = pd.read_csv('reviews_3.csv')

reviews = reviews_df['content'].tolist()

reviews = reviews_df['content'].tolist()

def classify_sentiment(text):
    blob = TextBlob(text)
    sentiment_polarity = blob.sentiment.polarity

    if sentiment_polarity > 0:
        return 'Positive'
    elif sentiment_polarity < 0:
        return 'Negative'
    else:
        return 'Neutral'

reviews_df['sentiment'] = reviews_df['content'].apply(classify_sentiment)

print(reviews_df)
# Out:
#         review_id  product_id  \
# 0  R2SSSH04J4J264  B0D4SX9RC6
# 1  R39X7USU3OX34C  B0D4SX9RC6
# 2   R4BQHA0TLLJNN  B0D4SX9RC6
# 3  R3SO3HMV0YC0WB  B0D4SX9RC6
# 4  R1BHCCLK5GZ5VZ  B0D4SX9RC6
# 5  R102ZHXOOGDR18  B0D4SX9RC6
# 6  R3EOM3PFJ90D5Y  B0D4SX9RC6
# 7  R2EVRTXO9M1YF7  B0D4SX9RC6
# 8   RTDXQGCW5S0SA  B0D4SX9RC6
# 9  R10YJBZGOB4SBS  B0D4SX9RC6
#
#                                                title            author  \
# 0  5.0 out of 5 stars Really nice portable speake...           Bruce C
# 1                     5.0 out of 5 stars Really good            Justin
# 2  5.0 out of 5 stars The best Speaker I have eve...              Leox
# 3                      5.0 out of 5 stars Beats pill  Bryan Pennington
# 4                      5.0 out of 5 stars Beats Pill  Gregory Stratman
# 5      5.0 out of 5 stars Amazing sound for the size            Maxy D
# 6  3.0 out of 5 stars Good design, but bass disto...            Daniel
# ...

# %%
# Positive, Negative and Neutral Sentiment
import pandas as pd
from textblob import TextBlob

reviews_df = pd.read_csv('reviews_4.csv')

reviews = reviews_df['content'].tolist()

reviews = reviews_df['content'].tolist()

def classify_sentiment(text):
    blob = TextBlob(text)
    sentiment_polarity = blob.sentiment.polarity

    if sentiment_polarity > 0:
        return 'Positive'
    elif sentiment_polarity < 0:
        return 'Negative'
    else:
        return 'Neutral'

reviews_df['sentiment'] = reviews_df['content'].apply(classify_sentiment)

print(reviews_df)
# Out:
#         review_id  product_id  \
# 0   RAZ6J396ABA0X  B09GJZKQ3K
# 1  R1R3MYC6YU5Z0P  B09GJZKQ3K
# 2  R260UY3O2FGTRG  B09GJZKQ3K
# 3   RVXOZ0RVT0SU5  B09GJZKQ3K
# 4  R2D3F5CB8TDT0C  B09GJZKQ3K
# 5  R3IHAMQG6HU1YF  B09GJZKQ3K
# 6   RY1NRL2ZT5UZE  B09GJZKQ3K
# 7   R8Q857TW6UHAJ  B09GJZKQ3K
# 8  R2SBQNUF0JYV5F  B09GJZKQ3K
# 9   RILMKXRAW75NM  B09GJZKQ3K
#
#                                                title            author  \
# 0  5.0 out of 5 stars Fantastic sound quality and...         Kassandra
# 1                   5.0 out of 5 stars Great Quality      Erika Ernest
# 2                   5.0 out of 5 stars Great speaker       Kari Maddox
# 3                         5.0 out of 5 stars IN LOVE       Israt Ahmed
# 4                     5.0 out of 5 stars Works great           Shinobu
# 5  4.0 out of 5 stars The performance you get in ...   Amazon Customer
# 6               5.0 out of 5 stars Big poolside hit!  Kimberly McGrath
# ...

# %%
# !pip install matplotlib
# !pip install pandas
# !pip install textblob

import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt

def classify_sentiment(text):
    blob = TextBlob(text)
    sentiment_polarity = blob.sentiment.polarity

    if sentiment_polarity > 0:
        return 'Positive'
    elif sentiment_polarity < 0:
        return 'Negative'
    else:
        return 'Neutral'

reviews_df_3 = pd.read_csv('reviews_3.csv')
reviews_3 = reviews_df_3['content'].tolist()
sentiment_3 = [classify_sentiment(review) for review in reviews_3]
sentiment_counts_3 = pd.Series(sentiment_3).value_counts()


reviews_df_4 = pd.read_csv('reviews_4.csv')
reviews_4 = reviews_df_4['content'].tolist()
sentiment_4 = [classify_sentiment(review) for review in reviews_4]
sentiment_counts_4 = pd.Series(sentiment_4).value_counts()


fig, ax = plt.subplots()

bar_width = 0.35
opacity = 0.8

rects1 = ax.bar(sentiment_counts_3.index, sentiment_counts_3.values, bar_width,
                alpha=opacity, color='b', label='Reviews 3')

rects2 = ax.bar(sentiment_counts_4.index, sentiment_counts_4.values, bar_width,
                alpha=opacity, color='g', label='Reviews 4')

ax.set_xlabel('Sentiment')
ax.set_ylabel('Number of Reviews')
ax.set_title('Sentiment Analysis Comparison')
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Reviews 3 (Beats Pill) has more reviews with a positive sentiment than reviews 4 (JBL Speaker) which has one negative review. This shows that the Beats Pill is still a strong competitor despite complaints.

# %% [markdown]
# Here is a comparison of the wordclouds made from the different speaker reviews.

# %%
# Import necessary libraries
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

# Load the dataframe containing the reviews
df = pd.read_csv('/content/reviews_4.csv')
text = " ".join(review for review in df.content)
# Create stopword list:
stopwords = set(STOPWORDS)

# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Import necessary libraries
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

# Load the dataframe containing the reviews
df = pd.read_csv('/content/reviews_5.csv')
text = " ".join(review for review in df.content)
# Create stopword list:
stopwords = set(STOPWORDS)

# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Import necessary libraries
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

# Load the dataframe containing the reviews
df = pd.read_csv('/content/reviews_6.csv')
text = " ".join(review for review in df.content)
# Create stopword list:
stopwords = set(STOPWORDS)

# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Import necessary libraries
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

# Load the dataframe containing the reviews
df = pd.read_csv('/content/reviews_8.csv')
text = " ".join(review for review in df.content)
# Create stopword list:
stopwords = set(STOPWORDS)

# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Import necessary libraries
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

# Load the dataframe containing the reviews
df = pd.read_csv('/content/reviews_9.csv')
text = " ".join(review for review in df.content)
# Create stopword list:
stopwords = set(STOPWORDS)

# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# **ANALYSIS OF WORDCLOUDS**
#
# Analysing the word clouds gives us clear information about what consumers think is most important about each one of the speakers. All the word clouds have speaker and sound as their largest and most frewuently occuring words, however, we can see what each product's strength is by looking further.
#
# We can see that Marshall reviews mention quality frequently. This suggests that the marshall speaker has the best sound quality.
#
# In the case of Sony, reviewers seemed to love the 'nice settings' 'bluetooth connectivity' and 'bass' of the speaker.
#
# Anker users seem to really like the price of the product as well as its connectictivity with their phones.
#
# Both sets of JBL reviews refer to the product's size as well as great Bluetooth connectivity.
#
# From the Beats Pill wordcloud in section 6.2, reviewers repeatedly praised the volume of the beats pill as well as its battery life.
#
# THROUGH THIS SIMPLE ANALYSIS, WE CAN SEE WHAT IS MOST IMPORTANT TO THE DIFFERENT CUSTOMER BASES.

# %% [markdown]
# FURTHER COMPARISON

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the datasets
df_beats = pd.read_csv('reviews_3.csv')
df_jbl = pd.read_csv('reviews_4.csv')
df_bose = pd.read_csv('reviews_5.csv')
df_sony = pd.read_csv('reviews_6.csv')
df_marshall = pd.read_csv('reviews_8.csv')
df_anker = pd.read_csv('reviews_9.csv')

# Combine the ratings into a single DataFrame for plotting
all_ratings = pd.concat([
    df_beats['rating'],
    df_jbl['rating'],
    df_bose['rating'],
    df_sony['rating'],
    df_marshall['rating'],
    df_anker['rating']
], axis=1)
all_ratings.columns = ['Beats', 'JBL', 'Bose', 'Sony', 'Marshall', 'Anker']

# Create a histogram to compare the distributions
plt.figure(figsize=(10, 6))
all_ratings.hist(bins=5, alpha=0.7)
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.title('Distribution of Ratings for Different Speaker Brands')
plt.legend(all_ratings.columns, loc='upper left')

# Adjust layout to prevent labels from overlapping
plt.tight_layout()
plt.show()

# %% [markdown]
# From the distribution above, we can see that Beats, Marshall and Sony have the same wide range for ratings.  Although most brands have ratings from 4.5-5.0, JBL and Bose have the majority of their ratings between 4.8 and 5.0.

# %% [markdown]
# FURTHER ANALYSIS OF REVIEW SENTIMENT OVER TIME

# %%
import pandas as pd
import matplotlib.pyplot as plt
from textblob import TextBlob

# Load the dataset
df_beats = pd.read_csv('reviews_3.csv')

# Check the column names
print(df_beats.columns)

# Extract the date from the 'date' column
df_beats['timestamp'] = df_beats['timestamp'].str.split('United States ').str[1]

# Convert the 'date' column to datetime objects
df_beats['timestamp'] = pd.to_datetime(df_beats['timestamp'])

# Function to calculate sentiment polarity
def get_sentiment(text):
    return TextBlob(text).sentiment.polarity

# Calculate sentiment polarity for each review
df_beats['sentiment'] = df_beats['content'].apply(get_sentiment)

# Group the reviews by month and calculate the average sentiment
monthly_sentiment = df_beats.groupby(pd.Grouper(key='timestamp', freq='M'))['sentiment'].mean()

# Create a line plot to visualize the trend of sentiment over time
plt.figure(figsize=(12, 6))
plt.plot(monthly_sentiment.index, monthly_sentiment.values)
plt.xlabel('Date')
plt.ylabel('Average Sentiment')
plt.title('Sentiment Trend for Beats Over Time')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Index(['review_id', 'product_id', 'title', 'author', 'rating', 'content',
#        'timestamp', 'profile_id', 'is_verified', 'helpful_count',
#        'product_attributes'],
#       dtype='object')
# /tmp/ipython-input-21-971211074.py:25: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_sentiment = df_beats.groupby(pd.Grouper(key='timestamp', freq='M'))['sentiment'].mean()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from textblob import TextBlob

# Load the dataset
df_beats = pd.read_csv('reviews_4.csv')

# Check the column names
print(df_beats.columns)

# Extract the date from the 'date' column
df_beats['timestamp'] = df_beats['timestamp'].str.split('United States ').str[1]

# Convert the 'date' column to datetime objects
df_beats['timestamp'] = pd.to_datetime(df_beats['timestamp'])

# Function to calculate sentiment polarity
def get_sentiment(text):
    return TextBlob(text).sentiment.polarity

# Calculate sentiment polarity for each review
df_beats['sentiment'] = df_beats['content'].apply(get_sentiment)

# Group the reviews by month and calculate the average sentiment
monthly_sentiment = df_beats.groupby(pd.Grouper(key='timestamp', freq='M'))['sentiment'].mean()

# Create a line plot to visualize the trend of sentiment over time
plt.figure(figsize=(12, 6))
plt.plot(monthly_sentiment.index, monthly_sentiment.values)
plt.xlabel('Date')
plt.ylabel('Average Sentiment')
plt.title('Sentiment Trend for JBL Flip 6 Over Time')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Index(['review_id', 'product_id', 'title', 'author', 'rating', 'content',
#        'timestamp', 'profile_id', 'is_verified', 'helpful_count',
#        'product_attributes'],
#       dtype='object')
# /tmp/ipython-input-22-3702812812.py:25: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_sentiment = df_beats.groupby(pd.Grouper(key='timestamp', freq='M'))['sentiment'].mean()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from textblob import TextBlob

# Load the dataset
df_beats = pd.read_csv('reviews_6.csv')

# Check the column names
print(df_beats.columns)

# Extract the date from the 'date' column
df_beats['timestamp'] = df_beats['timestamp'].str.split('United States ').str[1]

# Convert the 'date' column to datetime objects
df_beats['timestamp'] = pd.to_datetime(df_beats['timestamp'])

# Function to calculate sentiment polarity
def get_sentiment(text):
    return TextBlob(text).sentiment.polarity

# Calculate sentiment polarity for each review
df_beats['sentiment'] = df_beats['content'].apply(get_sentiment)

# Group the reviews by month and calculate the average sentiment
monthly_sentiment = df_beats.groupby(pd.Grouper(key='timestamp', freq='M'))['sentiment'].mean()

# Create a line plot to visualize the trend of sentiment over time
plt.figure(figsize=(12, 6))
plt.plot(monthly_sentiment.index, monthly_sentiment.values)
plt.xlabel('Date')
plt.ylabel('Average Sentiment')
plt.title('Sentiment Trend for SONY ULT Field 1 Over Time')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Index(['review_id', 'product_id', 'title', 'author', 'rating', 'content',
#        'timestamp', 'profile_id', 'is_verified', 'helpful_count',
#        'product_attributes'],
#       dtype='object')
# /tmp/ipython-input-23-2723243630.py:25: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_sentiment = df_beats.groupby(pd.Grouper(key='timestamp', freq='M'))['sentiment'].mean()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from textblob import TextBlob

# Load the dataset
df_beats = pd.read_csv('reviews_8.csv')

# Check the column names
print(df_beats.columns)

# Extract the date from the 'date' column
df_beats['timestamp'] = df_beats['timestamp'].str.split('United States ').str[1]

# Convert the 'date' column to datetime objects
df_beats['timestamp'] = pd.to_datetime(df_beats['timestamp'])

# Function to calculate sentiment polarity
def get_sentiment(text):
    return TextBlob(text).sentiment.polarity

# Calculate sentiment polarity for each review
df_beats['sentiment'] = df_beats['content'].apply(get_sentiment)

# Group the reviews by month and calculate the average sentiment
monthly_sentiment = df_beats.groupby(pd.Grouper(key='timestamp', freq='M'))['sentiment'].mean()

# Create a line plot to visualize the trend of sentiment over time
plt.figure(figsize=(12, 6))
plt.plot(monthly_sentiment.index, monthly_sentiment.values)
plt.xlabel('Date')
plt.ylabel('Average Sentiment')
plt.title('Sentiment Trend for Marshall Emberton II Over Time')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Index(['review_id', 'product_id', 'title', 'author', 'rating', 'content',
#        'timestamp', 'profile_id', 'is_verified', 'helpful_count',
#        'product_attributes'],
#       dtype='object')
# /tmp/ipython-input-24-1110320006.py:25: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_sentiment = df_beats.groupby(pd.Grouper(key='timestamp', freq='M'))['sentiment'].mean()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from textblob import TextBlob

# Load the dataset
df_beats = pd.read_csv('reviews_9.csv')

# Check the column names
print(df_beats.columns)

# Extract the date from the 'date' column
df_beats['timestamp'] = df_beats['timestamp'].str.split('United States ').str[1]

# Convert the 'date' column to datetime objects
df_beats['timestamp'] = pd.to_datetime(df_beats['timestamp'])

# Function to calculate sentiment polarity
def get_sentiment(text):
    return TextBlob(text).sentiment.polarity

# Calculate sentiment polarity for each review
df_beats['sentiment'] = df_beats['content'].apply(get_sentiment)

# Group the reviews by month and calculate the average sentiment
monthly_sentiment = df_beats.groupby(pd.Grouper(key='timestamp', freq='M'))['sentiment'].mean()

# Create a line plot to visualize the trend of sentiment over time
plt.figure(figsize=(12, 6))
plt.plot(monthly_sentiment.index, monthly_sentiment.values)
plt.xlabel('Date')
plt.ylabel('Average Sentiment')
plt.title('Sentiment Trend for ANKER SoundCore Over Time')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Index(['review_id', 'product_id', 'title', 'author', 'rating', 'content',
#        'timestamp', 'profile_id', 'is_verified', 'helpful_count',
#        'product_attributes'],
#       dtype='object')
# /tmp/ipython-input-25-1781740893.py:25: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_sentiment = df_beats.groupby(pd.Grouper(key='timestamp', freq='M'))['sentiment'].mean()

# %% [markdown]
# The above visualizations show us the trends for the different Beats Pill competitores. We can see how long they have been in the market as well as how their ratings have flunctuated.
#
# From August of 2024, the JBL speaker has gotten much worse reviews than previously. We can choose to explore exactly why that is to see if there is any shortfall that Beats can make up.
#
# Another observation is that the ANKER speaker's average ratings have never gone above 0.30, but the Marshall speaker's average ratings are currently around 0.50. Even though both are trending upwards, the Marshall Speaker seems to be faring better.

# %% [markdown]
# ### 8.3 SWOT Analysis

# %% [markdown]
# **Strengths:**
#
# Brand Reputation: As part of the Beats by Dre lineup, the Beats Pill 2024 benefits from strong brand recognition and a loyal customer base.
# Design and Portability: The Beats Pill has always been known for its sleek design and portability, making it a convenient choice for users who want a stylish, travel-friendly speaker.
# Sound Quality (At Moderate Volumes): Despite issues at higher volumes, the Beats Pill is generally praised for its sound quality at moderate levels, offering clear vocals and punchy bass.
# USB-C Compatibility: The inclusion of a USB-C port for wired audio is a modern touch that aligns with current technology standards.
#
# **Weaknesses:**
#
# App Functionality Issues: The lack of a dedicated app for the Beats Pill 2024 frustrates users who expect control over EQ settings and connectivity management.
#
# Sound Quality at Higher Volumes: The bass distortion when the volume is turned up detracts from the overall audio experience, which could be a significant drawback for users who expect premium sound quality across all levels.
#
# Limited Bluetooth Range: The relatively short Bluetooth range leads to interruptions when users move around, diminishing the convenience of wireless connectivity.
# Packaging Problems: Flimsy packaging raises concerns about the speaker being damaged during delivery, which negatively impacts customer satisfaction.
#
# **Opportunities:**
#
# App Development: Creating a dedicated app for the Beats Pill 2024 could significantly enhance user experience, allowing for greater control over settings like EQ, battery management, and connections.
#
# Improve Sound Design: Addressing the bass distortion at higher volumes could elevate the product's appeal, especially among audiophiles or users who often listen to music at high volumes.
#
# Enhance Bluetooth Range: Improving Bluetooth connectivity would extend the product’s utility and appeal, especially for users who need more flexibility when moving around.
#
# **Threats:**
#
# Competition from Other Brands: With many other brands offering portable Bluetooth speakers, issues like limited app functionality and sound distortion could push users to choose alternatives like JBL or Bose, which may offer better performance in these areas.
#
# Consumer Expectations for High-End Audio: As consumers increasingly expect premium sound quality at all volume levels, failing to address sound distortion could damage the brand's reputation in the competitive audio market.
#
# Evolving User Preferences: Users increasingly expect seamless experiences with products, and things like wired connection issues or packaging problems could lead to negative reviews, driving potential customers toward more user-friendly options.

# %% [markdown]
# ## 9. Strategic Recommendations
#
# ### 9.1 Product Improvements
# Based on the analysis, I suggest the following product improvements:

# %% [markdown]
# The Beats Pill can be improved by increasing its sound quality at high bass volumes and by the introduction of an app for seamless remote control of the speaker. This app should be available on both Android and Apple Operating Systems to ensure a wide reach of customers.

# %% [markdown]
# ### 9.2 Marketing Strategies
# Recommendations for marketing strategies that could enhance consumer perception and satisfaction.

# %% [markdown]
# The Beats Pill should play to its strengths of having an easile recognizable silhouette. For example, it could use an outline picture of the product to pay on the instant recognition.
#
# Additionally, it should further its collaborations with Apple, considering their past partnerships. It should also note the seamless integration with apple software.
#
# Furthermore, it should market its high sound quality at medium ranges for users who live with others who want a speaker that does not disturb guests. It can capitalize on having a softer, more refined sound.

# %% [markdown]
# ### 9.3 Future Research

# %% [markdown]
# More research can be done on the demographics of people who purchase the beats pill. Additionally, we could see what the most common demographic is for negative reviews and analyse what is most important to that segment of the market.

# %% [markdown]
# ## 10. Conclusion

# %% [markdown]
# The key findings from the data analysis show that although the Beats Pill has a dedicated, satisfied fanbase, there is still room for improvement to meet up with fierce compeition.
#
# This project has underscored the importance of consistent innovation on the Beats Pill and the key areas where it must be implemented i.e. App integration and Sound quality at high volumes.

# %% [markdown]
# ## 11. References

# %% [markdown]
# Google Colab
#
# Oxylabs Web Scraper
#
# Gemini AI
#
# Textblob
#
# NumPy
#
# Matplotlib
#
# Pandas
#
# Google Gemini AI
#
# Amazon.com
